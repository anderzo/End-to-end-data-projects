# %%
import pandas as pd

df = pd.read_json('tienda_dataset_2025.json')
print(df.shape)
print(df.describe())
# Out:
# (500, 24)
#        precio_unitario    cantidad  total_sin_descuento  descuento_porcentaje  \
# count       500.000000  500.000000           500.000000            500.000000
# mean        138.186000    2.348000           302.173560              4.740000
# std         180.406836    1.935559           511.624053              6.173218
# min           5.030000    1.000000             6.470000              0.000000
# 25%          36.447500    1.000000            58.057500              0.000000
# 50%          75.110000    2.000000           140.675000              0.000000
# 75%         160.337500    3.000000           347.257500             10.000000
# max        1148.440000   10.000000          7130.400000             20.000000
#
#        total_final  edad_cliente  satisfaccion_cliente  costo_envio  \
# count   500.000000    500.000000            500.000000   500.000000
# mean    289.129280     46.560000              4.152000     2.366380
# ...

# %%
print(df.isna().sum()) #no hay valores nulos
# Out:
# n_orden                 0
# nombre_empleado         0
# nombre_tienda           0
# ciudad                  0
# producto                0
# categoria               0
# precio_unitario         0
# cantidad                0
# total_sin_descuento     0
# descuento_porcentaje    0
# total_final             0
# forma_pago              0
# fecha                   0
# hora                    0
# dia_semana              0
# mes                     0
# genero_cliente          0
# edad_cliente            0
# rango_edad              0
# satisfaccion_cliente    0
# cliente_recurrente      0
# metodo_envio            0
# costo_envio             0
# margen_beneficio        0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['n_orden', 'nombre_empleado', 'nombre_tienda', 'ciudad', 'producto',
#        'categoria', 'precio_unitario', 'cantidad', 'total_sin_descuento',
#        'descuento_porcentaje', 'total_final', 'forma_pago', 'fecha', 'hora',
#        'dia_semana', 'mes', 'genero_cliente', 'edad_cliente', 'rango_edad',
#        'satisfaccion_cliente', 'cliente_recurrente', 'metodo_envio',
#        'costo_envio', 'margen_beneficio'],
#       dtype='str')

# %%
print(df.dtypes)
# Out:
# n_orden                     str
# nombre_empleado             str
# nombre_tienda               str
# ciudad                      str
# producto                    str
# categoria                   str
# precio_unitario         float64
# cantidad                  int64
# total_sin_descuento     float64
# descuento_porcentaje      int64
# total_final             float64
# forma_pago                  str
# fecha                       str
# hora                        str
# dia_semana                  str
# mes                         str
# genero_cliente              str
# edad_cliente              int64
# rango_edad                  str
# satisfaccion_cliente      int64
# cliente_recurrente         bool
# metodo_envio                str
# costo_envio             float64
# margen_beneficio        float64
# dtype: object

# %%
print(df['fecha'].head(2)) #fecha requiere un camnbio de formato de str a date
# Out:
# 0    2025-01-01
# 1    2025-01-02
# Name: fecha, dtype: str

# %%
print(df['hora'].head(2)) # se puede unir con la clumna fecha y dar formato de hora y fecha
# Out:
# 0    20:35:52
# 1    16:54:25
# Name: hora, dtype: str

# %%
print(df['ciudad'].value_counts())
# Out:
# ciudad
# Valencia     140
# Barcelona    131
# Madrid       118
# Sevilla      111
# Name: count, dtype: int64
